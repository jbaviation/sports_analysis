# %% [markdown]
# Compare aggregate winning percentages of US and Canadien cities with >2 of the big 4 professional sports teams in the past 40 years.
#
# I'm webscraping a variety of sources including:
#
# https://en.wikipedia.org/wiki/List_of_American_and_Canadian_cities_by_number_of_major_professional_sports_franchises
# https://en.wikipedia.org/wiki/Relocation_of_professional_sports_teams
# https://en.wikipedia.org/wiki/Major_professional_sports_teams_of_the_United_States_and_Canada
# https://www.baseball-reference.com
# https://www.pro-football-reference.com
# https://www.basketball-reference.com
# https://www.hockey-reference.com

# %%
import numpy as np
import pandas as pd

pd.set_option('max_colwidth',140)  # change max column width

# %% [markdown]
# Start by reading in the sports franchises by region

# %%
# Read the wiki table with list of sports franchises by region
site = 'https://en.wikipedia.org/wiki/List_of_American_and_Canadian_cities_by_number_of_major_professional_sports_franchises'
usecols = ['Metropolitan area', 'Country', 'Population (2016 est.)[8]','B4']

df_numf = pd.read_html(site,header=0)[1].loc[:,usecols]   # reads the correct dataframe

df_numf.rename(columns={'Metropolitan area': 'Region',
                        'Population (2016 est.)[8]': 'Population 2016'}, inplace=True)
df_numf = df_numf[df_numf['B4']>=3].drop(df_numf[df_numf['Region']=='Totals'].index)   # only use rows where big4 is greater than 2
df_numf
# Out:
#                     Region        Country Population 2016  B4
# 0            New York City  United States        20153634   9
# 1              Los Angeles  United States        13310447   8
# 2                  Chicago  United States         9512999   5
# 3   San Francisco Bay Area  United States         6657982   5
# 4        Dallas–Fort Worth  United States         7233323   4
# 5         Washington, D.C.  United States         6131977   4
# 6             Philadelphia  United States         6070500   4
# 7    Miami–Fort Lauderdale  United States         6066387   4
# 8                   Boston  United States         4794447   4
# 9   Minneapolis–Saint Paul  United States         3551036   4
# 10                  Denver  United States         2853077   4
# 11                 Phoenix  United States         4661537   4
# 12                 Detroit  United States         4297617   4
# 13                 Toronto         Canada         5928040   3
# 14                 Houston  United States         6772470   3
# 15                 Atlanta  United States         5789700   3
# 16          Tampa Bay Area  United States         3032171   3
# 17              Pittsburgh  United States         2342299   3
# 18               Cleveland  United States         2055612   3

# %% [markdown]
# Read the list of major pro sports teams

# %%
site = 'https://en.wikipedia.org/wiki/Major_professional_sports_teams_of_the_United_States_and_Canada'
usecols = ['Team', 'City', 'State/Province', 'League', 'Est.']
df_allteams = pd.read_html(site,header=0)[0].loc[:,usecols]  # read in all teams

df_allteams = (df_allteams.loc[df_allteams['League'].isin(['NBA','NFL','MLB','NHL'])]
               .reset_index(drop=True))  # only use teams in the big 4 leagues

# Change names of cities to allow for merging of data
names = {'Anaheim': 'Los Angeles',
         'Arlington': 'Dallas–Fort Worth',
         'Dallas': 'Dallas–Fort Worth',
         'East Rutherford': 'New York City',
         'Foxborough': 'Boston',
         'Glendale': 'Phoenix',
         'Inglewood': 'Los Angeles',
         'Landover': 'Washington, D.C.',
         'Miami Gardens': 'Miami–Fort Lauderdale',
         'Miami': 'Miami–Fort Lauderdale',
         'Minneapolis': 'Minneapolis–Saint Paul',
         'Newark': 'New York City',
         'Oakland': 'San Francisco Bay Area',
         'San Francisco': 'San Francisco Bay Area',
         'San Jose': 'San Francisco Bay Area',
         'Santa Clara': 'San Francisco Bay Area',
         'St. Paul': 'Minneapolis–Saint Paul',
         'St. Petersburg': 'Tampa Bay Area',
         'Sunrise': 'Miami–Fort Lauderdale',
         'Tampa': 'Tampa Bay Area',
         'Washington': 'Washington, D.C.'
        }
df_allteams.replace(names, inplace=True)

# %% [markdown]
# Merge the df_allteams and df_numf dataframes

# %%
cur_teams = pd.merge(df_numf, df_allteams, how='left', left_on='Region', right_on='City').drop('City',axis=1)

# check=df.sort_values('Est.',ascending=False)[df['Est.'].astype(int)>=1980]   # find teams that <40 years old

# Add rows based on the results of check
reg = ['Los Angeles','Los Angeles','Minneapolis–Saint Paul','Denver','Los Angeles','Phoenix','Chicago','Atlanta',
       'Los Angeles','Los Angeles','Los Angeles','Miami–Fort Lauderdale','Tampa Bay Area','New York City',
       'Washington, D.C.','Phoenix','San Francisco Bay Area','Houston']
tm = ['Los Angeles Rams','Los Angeles Raiders','Minnesota North Stars','Colorado Rockies',
      'Mighty Ducks of Anaheim','Phoenix Coyotes','Chicago Black Hawks','Atlanta Thrashers',
      'Anaheim Angels','California Angels','Los Angeles Angels of Anaheim','Florida Marlins',
      'Tampa Bay Devil Rays','New Jersey Nets','Washington Bullets','Phoenix Cardinals',
      'Oakland Raiders','Houston Oilers']
lg = ['NFL','NFL','NHL','NHL','NHL','NHL','NHL','NHL','MLB','MLB','MLB','MLB','MLB','NBA','NBA','NFL','NFL','NFL']
old_teams = pd.DataFrame({'Region': reg, 'Team': tm, 'League': lg})

# Combine old and new teams
df = pd.concat([cur_teams,old_teams],ignore_index=True,sort=False).sort_values(by='Region').reset_index(drop=True)

# Fill missing columns
cols = ['Country','Population 2016','B4','State/Province']
df.loc[:,cols] = df.groupby('Region')[cols].apply(lambda x: x.bfill())
df.loc[:,cols] = df.groupby('Region')[cols].apply(lambda x: x.ffill())

df
# Out:
#                     Region        Country Population 2016   B4  \
# 0                  Atlanta  United States         5789700  3.0
# 1                  Atlanta  United States         5789700  3.0
# 2                  Atlanta  United States         5789700  3.0
# 3                  Atlanta  United States         5789700  3.0
# 4                   Boston  United States         4794447  4.0
# 5                   Boston  United States         4794447  4.0
# 6                   Boston  United States         4794447  4.0
# 7                   Boston  United States         4794447  4.0
# 8                  Chicago  United States         9512999  5.0
# 9                  Chicago  United States         9512999  5.0
# 10                 Chicago  United States         9512999  5.0
# 11                 Chicago  United States         9512999  5.0
# 12                 Chicago  United States         9512999  5.0
# 13                 Chicago  United States         9512999  5.0
# 14               Cleveland  United States         2055612  3.0
# 15               Cleveland  United States         2055612  3.0
# 16               Cleveland  United States         2055612  3.0
# 17       Dallas–Fort Worth  United States         7233323  4.0
# 18       Dallas–Fort Worth  United States         7233323  4.0
# 19       Dallas–Fort Worth  United States         7233323  4.0
# 20       Dallas–Fort Worth  United States         7233323  4.0
# 21                  Denver  United States         2853077  4.0
# 22                  Denver  United States         2853077  4.0
# 23                  Denver  United States         2853077  4.0
# 24                  Denver  United States         2853077  4.0
# 25                  Denver  United States         2853077  4.0
# 26                 Detroit  United States         4297617  4.0
# 27                 Detroit  United States         4297617  4.0
# 28                 Detroit  United States         4297617  4.0
# 29                 Detroit  United States         4297617  4.0
# ..                     ...            ...             ...  ...
# 69            Philadelphia  United States         6070500  4.0
# 70            Philadelphia  United States         6070500  4.0
# 71            Philadelphia  United States         6070500  4.0
# 72                 Phoenix  United States         4661537  4.0
# 73                 Phoenix  United States         4661537  4.0
# 74                 Phoenix  United States         4661537  4.0
# 75                 Phoenix  United States         4661537  4.0
# 76                 Phoenix  United States         4661537  4.0
# 77                 Phoenix  United States         4661537  4.0
# 78              Pittsburgh  United States         2342299  3.0
# 79              Pittsburgh  United States         2342299  3.0
# 80              Pittsburgh  United States         2342299  3.0
# 81  San Francisco Bay Area  United States         6657982  5.0
# 82  San Francisco Bay Area  United States         6657982  5.0
# 83  San Francisco Bay Area  United States         6657982  5.0
# 84  San Francisco Bay Area  United States         6657982  5.0
# 85  San Francisco Bay Area  United States         6657982  5.0
# 86  San Francisco Bay Area  United States         6657982  5.0
# 87          Tampa Bay Area  United States         3032171  3.0
# 88          Tampa Bay Area  United States         3032171  3.0
# 89          Tampa Bay Area  United States         3032171  3.0
# 90          Tampa Bay Area  United States         3032171  3.0
# 91                 Toronto         Canada         5928040  3.0
# 92                 Toronto         Canada         5928040  3.0
# 93                 Toronto         Canada         5928040  3.0
# 94        Washington, D.C.  United States         6131977  4.0
# 95        Washington, D.C.  United States         6131977  4.0
# 96        Washington, D.C.  United States         6131977  4.0
# 97        Washington, D.C.  United States         6131977  4.0
# 98        Washington, D.C.  United States         6131977  4.0
#
#                      Team        State/Province League  Est.
# 0           Atlanta Hawks               Georgia    NBA  1968
# 1       Atlanta Thrashers               Georgia    NHL   NaN
# 2          Atlanta Braves               Georgia    MLB  1966
# 3         Atlanta Falcons               Georgia    NFL  1966
# 4    New England Patriots         Massachusetts    NFL  1960
# 5          Boston Red Sox         Massachusetts    MLB  1901
# 6          Boston Celtics         Massachusetts    NBA  1946
# 7           Boston Bruins         Massachusetts    NHL  1924
# 8       Chicago White Sox              Illinois    MLB  1901
# 9            Chicago Cubs              Illinois    MLB  1870
# 10    Chicago Black Hawks              Illinois    NHL   NaN
# 11          Chicago Bulls              Illinois    NBA  1966
# 12     Chicago Blackhawks              Illinois    NHL  1926
# 13          Chicago Bears              Illinois    NFL  1921
# 14    Cleveland Cavaliers                  Ohio    NBA  1970
# 15       Cleveland Browns                  Ohio    NFL  1946
# 16      Cleveland Indians                  Ohio    MLB  1901
# 17       Dallas Mavericks                 Texas    NBA  1980
# 18         Dallas Cowboys                 Texas    NFL  1960
# 19          Texas Rangers                 Texas    MLB  1972
# 20           Dallas Stars                 Texas    NHL  1993
# 21       Colorado Rockies              Colorado    MLB  1993
# 22         Denver Nuggets              Colorado    NBA  1967
# 23     Colorado Avalanche              Colorado    NHL  1995
# 24         Denver Broncos              Colorado    NFL  1960
# 25       Colorado Rockies              Colorado    NHL   NaN
# 26          Detroit Lions              Michigan    NFL  1934
# 27        Detroit Pistons              Michigan    NBA  1957
# 28      Detroit Red Wings              Michigan    NHL  1926
# 29         Detroit Tigers              Michigan    MLB  1901
# ..                    ...                   ...    ...   ...
# 69    Philadelphia Eagles          Pennsylvania    NFL  1933
# 70     Philadelphia 76ers          Pennsylvania    NBA  1963
# 71  Philadelphia Phillies          Pennsylvania    MLB  1883
# 72        Phoenix Coyotes               Arizona    NHL   NaN
# 73      Phoenix Cardinals               Arizona    NFL   NaN
# 74      Arizona Cardinals               Arizona    NFL  1988
# 75        Arizona Coyotes               Arizona    NHL  1996
# 76   Arizona Diamondbacks               Arizona    MLB  1998
# 77           Phoenix Suns               Arizona    NBA  1968
# 78    Pittsburgh Penguins          Pennsylvania    NHL  1967
# 79     Pittsburgh Pirates          Pennsylvania    MLB  1882
# 80    Pittsburgh Steelers          Pennsylvania    NFL  1933
# 81   San Francisco Giants            California    MLB  1958
# 82    San Francisco 49ers            California    NFL  1946
# 83      Oakland Athletics            California    MLB  1968
# 84  Golden State Warriors            California    NBA  1962
# 85        San Jose Sharks            California    NHL  1991
# 86        Oakland Raiders            California    NFL   NaN
# 87   Tampa Bay Buccaneers               Florida    NFL  1976
# 88    Tampa Bay Lightning               Florida    NHL  1992
# 89         Tampa Bay Rays               Florida    MLB  1998
# 90   Tampa Bay Devil Rays               Florida    MLB   NaN
# 91    Toronto Maple Leafs               Ontario    NHL  1923
# 92        Toronto Raptors               Ontario    NBA  1995
# 93      Toronto Blue Jays               Ontario    MLB  1977
# 94    Washington Capitals  District of Columbia    NHL  1974
# 95     Washington Wizards  District of Columbia    NBA  1973
# 96     Washington Bullets  District of Columbia    NBA   NaN
# 97   Washington Nationals  District of Columbia    MLB  2005
# 98    Washington Redskins              Maryland    NFL  1937
#
# [99 rows x 8 columns]

# %% [markdown]
# Read in the teams from the big 4 leagues from the -reference sites

# %%
# Read the leagues teams
leagues = ['hockey','baseball','basketball','pro-football']
sites = ['https://www.{}-reference.com/teams/'.format(league) for league in leagues]
hds = [0,0,0,1]  # header rows for the various sites
[dfh,dfb,dfbb,dff] = [pd.read_html(site,header=hd)[0] for site, hd in zip(sites, hds)]

# %%
dfh
# Out:
#                   Franchise   Lg  From    To  Yrs    GP     W     L      T  \
# 0             Anaheim Ducks  NHL  1993  2020   26  2055   973   804  107.0
# 1             Anaheim Ducks  NHL  2006  2020   14  1103   592   377    NaN
# 2   Mighty Ducks of Anaheim  NHL  1993  2006   12   952   381   427  107.0
# 3           Arizona Coyotes  NHL  1979  2020   40  3178  1311  1442  266.0
# 4           Arizona Coyotes  NHL  2014  2020    6   480   190   236    NaN
# 5           Phoenix Coyotes  NHL  1996  2014   17  1360   615   546   94.0
# 6             Winnipeg Jets  NHL  1979  1996   17  1338   506   660  172.0
# 7             Boston Bruins  NHL  1924  2020   95  6570  3208  2387  791.0
# 8            Buffalo Sabres  NHL  1970  2020   49  3889  1790  1530  409.0
# 9            Calgary Flames  NHL  1972  2020   47  3734  1739  1469  379.0
# 10           Calgary Flames  NHL  1980  2020   39  3098  1471  1209  271.0
# 11           Atlanta Flames  NHL  1972  1980    8   636   268   260  108.0
# 12      Carolina Hurricanes  NHL  1979  2020   40  3176  1325  1422  263.0
# 13      Carolina Hurricanes  NHL  1997  2020   22  1756   791   713   86.0
# 14         Hartford Whalers  NHL  1979  1997   18  1420   534   709  177.0
# 15       Chicago Blackhawks  NHL  1926  2020   93  6504  2788  2736  814.0
# 16       Chicago Blackhawks  NHL  1986  2020   33  2618  1220  1035  197.0
# 17      Chicago Black Hawks  NHL  1926  1986   60  3886  1568  1701  617.0
# 18       Colorado Avalanche  NHL  1979  2020   40  3178  1465  1314  261.0
# 19       Colorado Avalanche  NHL  1995  2020   24  1922   968   715  101.0
# 20         Quebec Nordiques  NHL  1979  1995   16  1256   497   599  160.0
# 21    Columbus Blue Jackets  NHL  2000  2020   19  1512   660   672   33.0
# 22             Dallas Stars  NHL  1967  2020   52  4115  1819  1689  459.0
# 23             Dallas Stars  NHL  1993  2020   26  2053  1061   719  125.0
# 24    Minnesota North Stars  NHL  1967  1993   26  2062   758   970  334.0
# 25        Detroit Red Wings  NHL  1926  2020   93  6505  2970  2547  815.0
# 26        Detroit Red Wings  NHL  1932  2020   87  6237  2872  2419  773.0
# 27          Detroit Falcons  NHL  1930  1932    2    92    34    41   17.0
# 28          Detroit Cougars  NHL  1926  1930    4   176    64    87   25.0
# 29          Edmonton Oilers  NHL  1979  2020   40  3179  1434  1318  262.0
# 30         Florida Panthers  NHL  1993  2020   26  2053   852   856  142.0
# 31        Los Angeles Kings  NHL  1967  2020   52  4116  1733  1800  424.0
# 32           Minnesota Wild  NHL  2000  2020   19  1511   724   583   55.0
# 33       Montreal Canadiens  NHL  1917  2020  102  6731  3449  2281  837.0
# 34      Nashville Predators  NHL  1998  2020   21  1675   821   633   60.0
# 35        New Jersey Devils  NHL  1974  2020   45  3577  1515  1572  328.0
# 36        New Jersey Devils  NHL  1982  2020   37  2937  1375  1181  219.0
# 37         Colorado Rockies  NHL  1976  1982    6   480   113   281   86.0
# 38       Kansas City Scouts  NHL  1974  1976    2   160    27   110   23.0
# 39       New York Islanders  NHL  1972  2020   47  3732  1656  1570  347.0
# 40         New York Rangers  NHL  1926  2020   93  6504  2856  2693  808.0
# 41          Ottawa Senators  NHL  1992  2020   27  2139   948   912  115.0
# 42      Philadelphia Flyers  NHL  1967  2020   52  4115  2054  1429  457.0
# 43      Pittsburgh Penguins  NHL  1967  2020   52  4115  1866  1718  383.0
# 44          San Jose Sharks  NHL  1991  2020   28  2218  1049   892  121.0
# 45          St. Louis Blues  NHL  1967  2020   52  4117  1902  1625  432.0
# 46      Tampa Bay Lightning  NHL  1992  2020   27  2138   949   930  112.0
# 47      Toronto Maple Leafs  NHL  1917  2020  102  6730  2965  2815  783.0
# 48      Toronto Maple Leafs  NHL  1926  2020   93  6504  2853  2706  778.0
# 49     Toronto St. Patricks  NHL  1919  1926    7   186    94    87    5.0
# 50           Toronto Arenas  NHL  1917  1919    2    40    18    22    0.0
# 51        Vancouver Canucks  NHL  1970  2020   49  3889  1626  1717  391.0
# 52     Vegas Golden Knights  NHL  2017  2020    3   235   133    80    NaN
# 53      Washington Capitals  NHL  1974  2020   45  3577  1664  1452  303.0
# 54            Winnipeg Jets  NHL  1999  2020   20  1595   694   706   45.0
# 55            Winnipeg Jets  NHL  2011  2020    9   693   352   269    NaN
# 56        Atlanta Thrashers  NHL  1999  2011   11   902   342   437   45.0
#
#        OL   PTS   PTS%  Yrs Plyf  Div  Conf  Champ  St Cup
# 0   171.0  2224  0.541        14    6     2    1.0     1.0
# 1   134.0  1318  0.597        10    6     1    1.0     1.0
# 2    37.0   906  0.476         4    0     1    0.0     0.0
# 3   159.0  3047  0.479        19    1     0    0.0     0.0
# 4    54.0   434  0.452         0    0     0    0.0     0.0
# 5   105.0  1429  0.525         8    1     0    0.0     0.0
# 6     NaN  1184  0.442        11    0     0    0.0     0.0
# 7   184.0  7391  0.562        72   29     5    6.0     6.0
# 8   160.0  4149  0.533        29    6     1    0.0     0.0
# 9   147.0  4004  0.536        29    7     3    1.0     1.0
# 10  147.0  3360  0.542        23    7     3    1.0     1.0
# 11    NaN   644  0.506         6    0     0    0.0     0.0
# 12  166.0  3079  0.485        14    4     2    1.0     1.0
# 13  166.0  1834  0.522         6    3     2    1.0     1.0
# 14    NaN  1245  0.438         8    1     0    0.0     0.0
# 15  166.0  6556  0.504        62   17     4    6.0     6.0
# 16  166.0  2803  0.535        21    6     4    3.0     3.0
# 17    NaN  3753  0.483        41   11     0    3.0     3.0
# 18  138.0  3329  0.524        24   11     2    2.0     2.0
# 19  138.0  2175  0.566        15    9     2    2.0     2.0
# 20    NaN  1154  0.459         9    2     0    0.0     0.0
# 21  147.0  1500  0.496         5    0     0    0.0     0.0
# 22  148.0  4245  0.516        32   10     3    1.0     1.0
# 23  148.0  2395  0.583        15    8     2    1.0     1.0
# 24    NaN  1850  0.449        17    2     1    0.0     0.0
# 25  173.0  6928  0.533        64   29     6   11.0    11.0
# 26  173.0  6690  0.536        62   29     6   11.0    11.0
# 27    NaN    85  0.462         1    0     0    0.0     0.0
# 28    NaN   153  0.435         1    0     0    0.0     0.0
# 29  165.0  3295  0.518        21    6     7    5.0     5.0
# 30  203.0  2049  0.499         5    2     1    0.0     0.0
# 31  159.0  4049  0.492        30    1     3    2.0     2.0
# 32  149.0  1652  0.547         9    1     0    0.0     0.0
# 33  164.0  7899  0.587        83   37     3   25.0    23.0
# 34  161.0  1863  0.556        12    2     1    0.0     0.0
# 35  162.0  3520  0.492        23    9     5    3.0     3.0
# 36  162.0  3131  0.533        22    9     5    3.0     3.0
# 37    NaN   312  0.325         1    0     0    0.0     0.0
# 38    NaN    77  0.241         0    0     0    0.0     0.0
# 39  159.0  3818  0.512        25    6     3    4.0     4.0
# 40  147.0  6667  0.513        59    8     2    4.0     4.0
# 41  164.0  2175  0.508        16    4     1    0.0     0.0
# 42  175.0  4740  0.576        39   16     4    2.0     2.0
# 43  148.0  4263  0.518        34    9     6    5.0     5.0
# 44  156.0  2375  0.535        21    6     1    0.0     0.0
# 45  158.0  4394  0.534        42   10     1    1.0     1.0
# 46  147.0  2157  0.504        11    4     2    1.0     1.0
# 47  167.0  6880  0.511        68    8     0   13.0    13.0
# 48  167.0  6651  0.511        64    7     0   11.0    11.0
# 49    NaN   193  0.519         3    1     0    1.0     1.0
# 50    NaN    36  0.450         1    0     0    1.0     1.0
# 51  155.0  3798  0.488        27   10     3    0.0     0.0
# 52   22.0   288  0.613         2    2     1    NaN     NaN
# 53  158.0  3789  0.530        29   13     2    1.0     1.0
# 54  150.0  1583  0.496         4    1     0    0.0     0.0
# 55   72.0   776  0.560         3    0     0    0.0     0.0
# 56   78.0   807  0.447         1    1     0    0.0     0.0

# %% [markdown]
# ## Get winning percentages for each team in the df dataframe
# Start by reading the team IDs from each page (**WARNING THIS STEP CAN TAKE SEVERAL MINUTES TO RUN**)

# %%
bid = ['ATL', 'ARI', 'BAL', 'BOS', 'CHC', 'CHW', 'CIN', 'CLE', 'COL', 'DET',
       'KCR', 'HOU', 'LAA', 'LAD', 'MIA', 'MIL', 'MIN', 'NYM', 'NYY', 'OAK',
       'PHI', 'PIT', 'SDP', 'SEA', 'SFG', 'STL', 'TBR', 'TEX', 'TOR', 'WSN']
hid = ['ANA', 'PHX', 'BOS', 'BUF', 'CGY', 'CAR', 'CHI', 'COL', 'CBJ', 'DAL',
       'DET', 'EDM', 'FLA', 'LAK', 'MIN', 'MTL', 'NSH', 'NJD', 'NYI', 'NYR',
       'OTT', 'PHI', 'PIT', 'SJS', 'STL', 'TBL', 'TOR', 'VAN', 'VEG', 'WSH',
       'WPG']
bbid= ['ATL', 'BOS', 'NJN', 'CHA', 'CHI', 'CLE', 'DAL', 'DEN', 'DET', 'GSW',
       'HOU', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 'MIN', 'NOH', 'NYK',
       'OKC', 'ORL', 'PHI', 'PHO', 'POR', 'SAC', 'SAS', 'TOR', 'UTA', 'WAS']
fid = ['crd', 'atl', 'rav', 'buf', 'car', 'chi', 'cin', 'cle', 'dal', 'den',
       'det', 'gnb', 'htx', 'clt', 'jax', 'kan', 'sdg', 'ram', 'mia', 'min',
       'nwe', 'nor', 'nyg', 'nyj', 'rai', 'phi', 'pit', 'sfo', 'sea', 'tam',
       'oti', 'was']

# %%
# Hockey
h_franc = []
for team in hid:
    print('reading {} in {}'.format(team,leagues[0]))
    link = 'https://www.{}-reference.com/teams/{}/history.html'.format(leagues[0],team)
    try:
        read = pd.read_html(link,header=0)[0]
        h_franc.append(read)
    except:
        print('{} could NOT be accessed at \n{}'.format(team,link))
# Out:
# reading ANA in hockey
# reading PHX in hockey
# reading BOS in hockey
# reading BUF in hockey
# reading CGY in hockey
# reading CAR in hockey
# reading CHI in hockey
# reading COL in hockey
# reading CBJ in hockey
# reading DAL in hockey
# reading DET in hockey
# reading EDM in hockey
# reading FLA in hockey
# reading LAK in hockey
# reading MIN in hockey
# reading MTL in hockey
# reading NSH in hockey
# reading NJD in hockey
# reading NYI in hockey
# reading NYR in hockey
# reading OTT in hockey
# reading PHI in hockey
# reading PIT in hockey
# reading SJS in hockey
# reading STL in hockey
# reading TBL in hockey
# reading TOR in hockey
# reading VAN in hockey
# reading VEG in hockey
# reading WSH in hockey
# reading WPG in hockey

# %%
# Baseball
b_franc = []
for team in bid:
    print('reading {} in {}'.format(team,leagues[1]))
    link = 'https://www.{}-reference.com/teams/{}/'.format(leagues[1],team)
    try:
        read = pd.read_html(link,header=0)[0]
        b_franc.append(read)
    except:
        print('{} could NOT be accessed at \n{}'.format(team,link))
# Out:
# reading ATL in baseball
# reading ARI in baseball
# reading BAL in baseball
# reading BOS in baseball
# reading CHC in baseball
# reading CHW in baseball
# reading CIN in baseball
# reading CLE in baseball
# reading COL in baseball
# reading DET in baseball
# reading KCR in baseball
# reading HOU in baseball
# reading LAA in baseball
# reading LAD in baseball
# reading MIA in baseball
# reading MIL in baseball
# reading MIN in baseball
# reading NYM in baseball
# reading NYY in baseball
# reading OAK in baseball
# reading PHI in baseball
# reading PIT in baseball
# reading SDP in baseball
# reading SEA in baseball
# reading SFG in baseball
# reading STL in baseball
# reading TBR in baseball
# reading TEX in baseball
# reading TOR in baseball
# reading WSN in baseball

# %%
# Basketball
bb_franc = []
for team in bbid:
    print('reading {} in {}'.format(team,leagues[2]))
    link = 'https://www.{}-reference.com/teams/{}/'.format(leagues[2],team)
    try:
        read = pd.read_html(link,header=0)[0]
        bb_franc.append(read)
    except:
        print('{} could NOT be accessed at \n{}'.format(team,link))
# Out:
# reading ATL in basketball
# reading BOS in basketball
# reading NJN in basketball
# reading CHA in basketball
# reading CHI in basketball
# reading CLE in basketball
# reading DAL in basketball
# reading DEN in basketball
# reading DET in basketball
# reading GSW in basketball
# reading HOU in basketball
# reading IND in basketball
# reading LAC in basketball
# reading LAL in basketball
# reading MEM in basketball
# reading MIA in basketball
# reading MIL in basketball
# reading MIN in basketball
# reading NOH in basketball
# reading NYK in basketball
# reading OKC in basketball
# reading ORL in basketball
# reading PHI in basketball
# reading PHO in basketball
# reading POR in basketball
# reading SAC in basketball
# reading SAS in basketball
# reading TOR in basketball
# reading UTA in basketball
# reading WAS in basketball

# %%
# Football
f_franc = []
for team in fid:
    print('reading {} in {}'.format(team,leagues[3]))
    link = 'https://www.{}-reference.com/teams/{}/'.format(leagues[3],team)
    try:
        read = pd.read_html(link,header=1)[0]
        f_franc.append(read)
    except:
        print('{} could NOT be accessed at \n{}'.format(team,link))
# Out:
# reading crd in pro-football
# reading atl in pro-football
# reading rav in pro-football
# reading buf in pro-football
# reading car in pro-football
# reading chi in pro-football
# reading cin in pro-football
# reading cle in pro-football
# reading dal in pro-football
# reading den in pro-football
# reading det in pro-football
# reading gnb in pro-football
# reading htx in pro-football
# reading clt in pro-football
# reading jax in pro-football
# reading kan in pro-football
# reading sdg in pro-football
# reading ram in pro-football
# reading mia in pro-football
# reading min in pro-football
# reading nwe in pro-football
# reading nor in pro-football
# reading nyg in pro-football
# reading nyj in pro-football
# reading rai in pro-football
# reading phi in pro-football
# reading pit in pro-football
# reading sfo in pro-football
# reading sea in pro-football
# reading tam in pro-football
# reading oti in pro-football
# reading was in pro-football

# %% [markdown]
# Clean the data from h_franc, b_franc, bb_fran, f_franc
#
# **NOTE: these are lists of dataframes of each sport**

# %%
for df_team in h_franc+b_franc+bb_franc+f_franc:
    df_team.rename(columns={'Tm':'Team',
                            'Year':'Season',
                            'W-L%':'W/L%',
                            'Ties': 'T',
                            'Lg': 'League'} ,inplace=True)  # change column names to match the rest
    df_team.dropna(axis=1, how='all', inplace=True)  # drop columns that dont contain data
    df_team.dropna(axis=0, how='all', inplace=True)  # drop rows that dont contain data
    df_team['Team'] = df_team['Team'].replace({'\\xa0':' ', '[*]':''},regex=True)  # replace errant characters
    
    # Cleanup the season format (drop the "-") and convert to integer
    df_team['Season'] = df_team.apply(lambda row: str(row['Season']).split('-')[0],axis=1)
    df_team.drop(df_team[~df_team['Season'].str.isnumeric()].index, inplace=True)   # only use numeric
    df_team.drop(df_team[df_team['Season'].isna()].index, inplace=True)             # only use non-nans
    df_team['Season'] = df_team['Season'].astype(int)   # convert to integers
    

# Calculate the winning percentage in football
def winpct(row):
    try:
        tot = float(row['W']) + float(row['L']) + float(row['T'])
    except:
        print('failed on \n{}'.format(row))
    return (float(row['W']) + float(row['T'])/2.0) / tot

for df_team in f_franc:
    df_team['W/L%'] = df_team.apply(winpct, axis=1)

# Baseball uses division for the league, so it needs to be cleaned
for df_team in b_franc:
    df_team.rename(columns={'League': 'Division'},inplace=True)
    df_team['League'] = 'MLB'
    
f_franc[0]
# Out:
#      Season League                    Team   W   L  T Div. Finish    Playoffs  \
# 0      2019    NFL       Arizona Cardinals   5  10  1    4th of 4         NaN
# 1      2018    NFL       Arizona Cardinals   3  13  0    4th of 4         NaN
# 2      2017    NFL       Arizona Cardinals   8   8  0    3rd of 4         NaN
# 3      2016    NFL       Arizona Cardinals   7   8  1    2nd of 4         NaN
# 4      2015    NFL       Arizona Cardinals  13   3  0    1st of 4   Lost Conf
# 5      2014    NFL       Arizona Cardinals  11   5  0    2nd of 4     Lost WC
# 6      2013    NFL       Arizona Cardinals  10   6  0    3rd of 4         NaN
# 7      2012    NFL       Arizona Cardinals   5  11  0    4th of 4         NaN
# 8      2011    NFL       Arizona Cardinals   8   8  0    2nd of 4         NaN
# 9      2010    NFL       Arizona Cardinals   5  11  0    4th of 4         NaN
# 10     2009    NFL       Arizona Cardinals  10   6  0    1st of 4    Lost Div
# 11     2008    NFL       Arizona Cardinals   9   7  0    1st of 4     Lost SB
# 12     2007    NFL       Arizona Cardinals   8   8  0    2nd of 4         NaN
# 13     2006    NFL       Arizona Cardinals   5  11  0    4th of 4         NaN
# 14     2005    NFL       Arizona Cardinals   5  11  0    3rd of 4         NaN
# 15     2004    NFL       Arizona Cardinals   6  10  0    3rd of 4         NaN
# 16     2003    NFL       Arizona Cardinals   4  12  0    4th of 4         NaN
# 17     2002    NFL       Arizona Cardinals   5  11  0    4th of 4         NaN
# 18     2001    NFL       Arizona Cardinals   7   9  0    4th of 5         NaN
# 19     2000    NFL       Arizona Cardinals   3  13  0    5th of 5         NaN
# 20     1999    NFL       Arizona Cardinals   6  10  0    4th of 5         NaN
# 21     1998    NFL       Arizona Cardinals   9   7  0    2nd of 5    Lost Div
# 22     1997    NFL       Arizona Cardinals   4  12  0    5th of 5         NaN
# 23     1996    NFL       Arizona Cardinals   7   9  0    4th of 5         NaN
# 24     1995    NFL       Arizona Cardinals   4  12  0    5th of 5         NaN
# 25     1994    NFL       Arizona Cardinals   8   8  0    3rd of 5         NaN
# 26     1993    NFL       Phoenix Cardinals   7   9  0    4th of 5         NaN
# 27     1992    NFL       Phoenix Cardinals   4  12  0    5th of 5         NaN
# 28     1991    NFL       Phoenix Cardinals   4  12  0    5th of 5         NaN
# 29     1990    NFL       Phoenix Cardinals   5  11  0    5th of 5         NaN
# ..      ...    ...                     ...  ..  .. ..         ...         ...
# 74     1949    NFL       Chicago Cardinals   6   5  1    3rd of 5         NaN
# 75     1948    NFL       Chicago Cardinals  11   1  0    1st of 5  Lost Champ
# 76     1947    NFL       Chicago Cardinals   9   3  0    1st of 5   Won Champ
# 77     1946    NFL       Chicago Cardinals   6   5  0    3rd of 5         NaN
# 78     1945    NFL       Chicago Cardinals   1   9  0    5th of 5         NaN
# 79     1944    NFL  Chi/Pit Cards/Steelers   0  10  0    5th of 5         NaN
# 80     1943    NFL       Chicago Cardinals   0  10  0    4th of 4         NaN
# 81     1942    NFL       Chicago Cardinals   3   8  0    4th of 5         NaN
# 82     1941    NFL       Chicago Cardinals   3   7  1    4th of 5         NaN
# 83     1940    NFL       Chicago Cardinals   2   7  2    5th of 5         NaN
# 84     1939    NFL       Chicago Cardinals   1  10  0    5th of 5         NaN
# 85     1938    NFL       Chicago Cardinals   2   9  0    5th of 5         NaN
# 86     1937    NFL       Chicago Cardinals   5   5  1    4th of 5         NaN
# 87     1936    NFL       Chicago Cardinals   3   8  1    4th of 4         NaN
# 88     1935    NFL       Chicago Cardinals   6   4  2    3rd of 4         NaN
# 89     1934    NFL       Chicago Cardinals   5   6  0    4th of 6         NaN
# 90     1933    NFL       Chicago Cardinals   1   9  1    5th of 5         NaN
# 91     1932    NFL       Chicago Cardinals   2   6  2    6th of 8         NaN
# 92     1931    NFL       Chicago Cardinals   5   4  0   4th of 10         NaN
# 93     1930    NFL       Chicago Cardinals   5   6  2   7th of 11         NaN
# 96     1929    NFL       Chicago Cardinals   6   6  1   4th of 12         NaN
# 97     1928    NFL       Chicago Cardinals   1   5  0   9th of 10         NaN
# 98     1927    NFL       Chicago Cardinals   3   7  1   9th of 12         NaN
# 99     1926    NFL       Chicago Cardinals   5   6  1  10th of 22         NaN
# 100    1925    NFL       Chicago Cardinals  11   2  1   1st of 20   Won Champ
# 101    1924    NFL       Chicago Cardinals   5   4  1   8th of 18         NaN
# 102    1923    NFL       Chicago Cardinals   8   4  0   6th of 20         NaN
# 103    1922    NFL       Chicago Cardinals   8   3  0   3rd of 18         NaN
# 104    1921   APFA       Chicago Cardinals   3   3  2   8th of 21         NaN
# 105    1920   APFA       Chicago Cardinals   6   2  2   4th of 14         NaN
#
#       PF   PA  ... T/G Pts± Yds± out of    MoV    SoS    SRS  OSRS   DSRS  \
# 0    361  442  ...  18   23   29     32   -5.1    1.8   -3.2  -0.3   -2.9
# 1    225  425  ...  29   32   32     32  -12.5    1.0  -11.5  -9.6   -1.9
# 2    295  361  ...  23   24   15     32   -4.1    0.4   -3.7  -4.0    0.2
# 3    418  362  ...  17    7    1     32    3.5   -1.9    1.6   2.4   -0.8
# 4    489  313  ...   4    2    2     32   11.0    1.3   12.3   9.0    3.4
# 5    310  299  ...   5   16   27     32    0.7    1.3    2.0  -2.4    4.4
# 6    379  324  ...  17   10    7     32    3.4    3.0    6.4   2.7    3.7
# 7    250  357  ...  17   27   31     32   -6.7    3.5   -3.2  -4.8    1.6
# 8    312  348  ...  28   21   25     32   -2.3    0.0   -2.2  -1.7   -0.5
# 9    289  434  ...  22   31   32     32   -9.1   -3.6  -12.7  -5.6   -7.1
# 10   375  325  ...  24   12   17     32    3.1   -3.4   -0.3   0.1   -0.4
# 11   427  426  ...  17   18   11     32    0.1   -1.9   -1.9   4.1   -6.0
# 12   404  399  ...  22   15   13     32    0.3   -4.3   -3.9   1.9   -5.9
# 13   314  389  ...  12   25   25     32   -4.7   -2.2   -6.9  -2.6   -4.3
# 14   311  387  ...  30   23    3     32   -4.8   -0.2   -5.0  -2.0   -3.0
# 15   284  322  ...  18   21   26     32   -2.4   -2.5   -4.9  -5.1    0.2
# 16   225  452  ...  30   32   28     32  -14.2    1.6  -12.6  -6.3   -6.2
# 17   262  417  ...  27   31   30     32   -9.7   -0.2   -9.9  -5.4   -4.5
# 18   295  343  ...  18   21   29     31   -3.0   -1.2   -4.2  -1.5   -2.6
# 19   210  443  ...  30   30   27     31  -14.6   -0.7  -15.2  -7.2   -8.1
# 20   245  382  ...  30   27   29     31   -8.6   -0.2   -8.8  -5.5   -3.2
# 21   325  378  ...  11   18   17     30   -3.3   -4.1   -7.4  -1.6   -5.8
# 22   283  379  ...  29   27   29     30   -6.0   -0.4   -6.4  -2.6   -3.8
# 23   300  397  ...  26   26   17     30   -6.1   -1.4   -7.5  -1.7   -5.8
# 24   275  422  ...  16   29   27     30   -9.2    1.7   -7.5  -3.5   -4.0
# 25   235  267  ...   8   17   10     28   -2.0   -0.3   -2.3  -5.6    3.3
# 26   326  269  ...  21    8   14     28    3.6    0.4    3.9   1.9    2.1
# 27   243  332  ...  26   23   19     28   -5.6    2.5   -3.1  -2.9   -0.1
# 28   196  344  ...  14   24   27     28   -9.3    3.8   -5.4  -4.9   -0.5
# 29   268  396  ...  22   26   19     28   -8.0    1.3   -6.7  -1.9   -4.8
# ..   ...  ...  ...  ..  ...  ...    ...    ...    ...    ...   ...    ...
# 74   360  301  ...   2    4    7     10    4.9   -0.2    4.7   7.8   -3.1
# 75   395  226  ...   1    3    4     10   14.1   -0.9   13.2   9.9    3.3
# 76   306  231  ...   3    2    4     10    6.3    1.9    8.1   4.4    3.7
# 77   260  198  ...   6    3    3     10    5.6   -0.6    5.1   4.5    0.6
# 78    98  228  ...   9    9    7     10  -13.0    4.8   -8.2  -7.0   -1.2
# 79   108  328  ...  10   10    9     11  -22.0    4.1  -17.9  -5.5  -12.3
# 80    95  238  ...   8    7    7     10  -14.3    3.9  -10.4  -9.1   -1.4
# 81    98  209  ...   8    9    6     10  -10.1    2.5   -7.5  -7.0   -0.5
# 82   127  197  ...   5    6    5     10   -6.4    4.8   -1.6  -3.3    1.8
# 83   139  222  ...   7    8    8     10   -7.5    3.3   -4.3  -1.3   -2.9
# 84    84  254  ...   9   10   10     10  -15.5    5.8   -9.6  -5.5   -4.2
# 85   111  168  ...   8    8    6     10   -5.2    2.4   -2.8  -2.8    0.0
# 86   135  165  ...   3    7    7     10   -2.7    2.6   -0.2   0.1   -0.2
# 87    74  143  ...   2    6    5      9   -5.8    4.3   -1.4  -4.9    3.5
# 88    99   97  ...   6    5    6      9    0.2    2.5    2.7  -2.0    4.7
# 89    80   84  ...   5    7    6     11   -0.4    2.7    2.3  -3.6    5.9
# 90    52  101  ...   8    7    8     10   -4.5   -0.3   -4.7  -4.0   -0.8
# 91    72  114  ...   1    6    4      8   -4.2    1.1   -3.1   0.2   -3.3
# 92   120  128  ...   1    5    1     10   -0.9    3.9    3.0   5.4   -2.3
# 93   128  132  ...   1    6    1     11   -0.3    1.4    1.1  -0.6    1.7
# 96   154   83  ...   1    3    1     12    5.5    0.2    5.7   2.2    3.5
# 97     7  107  ...   1    9    1     10  -16.7    1.1  -15.6  -7.8   -7.7
# 98    69  134  ...   1    9    1     12   -5.9    4.5   -1.4  -0.3   -1.1
# 99    74   98  ...   1   12    1     22   -2.0    3.0    1.0  -0.4    1.4
# 100  230   65  ...   1    2    1     20   11.8  -10.1    1.7   1.3    0.4
# 101   90   67  ...   1    8    1     18    2.3   -6.4   -4.1  -4.1    0.0
# 102  161   56  ...   1    2    1     20    8.8   -7.1    1.7   1.0    0.6
# 103   96   50  ...   1    7    1     18    4.2   -5.0   -0.9  -1.7    0.9
# 104   54   53  ...   1   11    1     21    0.1   -2.6   -2.4  -3.2    0.7
# 105  115   43  ...   1    8    1     14    7.2   -1.9    5.3   1.3    4.0
#
#          W/L%
# 0    0.343750
# 1    0.187500
# 2    0.500000
# 3    0.468750
# 4    0.812500
# 5    0.687500
# 6    0.625000
# 7    0.312500
# 8    0.500000
# 9    0.312500
# 10   0.625000
# 11   0.562500
# 12   0.500000
# 13   0.312500
# 14   0.312500
# 15   0.375000
# 16   0.250000
# 17   0.312500
# 18   0.437500
# 19   0.187500
# 20   0.375000
# 21   0.562500
# 22   0.250000
# 23   0.437500
# 24   0.250000
# 25   0.500000
# 26   0.437500
# 27   0.250000
# 28   0.250000
# 29   0.312500
# ..        ...
# 74   0.541667
# 75   0.916667
# 76   0.750000
# 77   0.545455
# 78   0.100000
# 79   0.000000
# 80   0.000000
# 81   0.272727
# 82   0.318182
# 83   0.272727
# 84   0.090909
# 85   0.181818
# 86   0.500000
# 87   0.291667
# 88   0.583333
# 89   0.454545
# 90   0.136364
# 91   0.300000
# 92   0.555556
# 93   0.461538
# 96   0.500000
# 97   0.166667
# 98   0.318182
# 99   0.458333
# 100  0.821429
# 101  0.550000
# 102  0.666667
# 103  0.727273
# 104  0.500000
# 105  0.700000
#
# [100 rows x 30 columns]

# %% [markdown]
# Create functions to:
#  - merge df with each team in h_franc, b_franc, bb_franc, and f_franc
#  - groupby region and aggregate avg winning % making sure that the count is GE chosen number of teams

# %%
# Function to perform df combination
def combine_dfs(year_start=1980):
    # Create a copy of the original df and set the index for merging
    df_comb = df.copy().set_index(['Team','League'])

    # Add columns for the years of interest
    for yr in np.arange(year_start,2020):
        df_comb[yr] = np.nan

    # Pivot each of the df_teams from year_start-2019 then merge (using update) with df_comb dataframe
    for df_team in h_franc:
        # Use PT% for winning pct in hockey
        df_pvt = df_team[df_team['Season']>=year_start].pivot_table(values='PTS%',index=['Team','League'],columns='Season')
        df_comb.update(df_pvt)

    for df_team in b_franc+bb_franc+f_franc:
        # Use W/L% for winnning pct in the rest
        df_pvt = df_team[df_team['Season']>=year_start].pivot_table(values='W/L%',index=['Team','League'],columns='Season')
        df_comb.update(df_pvt)
        
    return df_comb.reset_index().set_index('Team')
    
def group_dfs(df_comb, num_teams=4):
    df_grp = df_comb.reset_index().groupby('Region').agg(['mean','count']).drop(columns='B4').T  # if need count too
    # df_grp.index.get_level_values(level=1)  # check level 1 of the index

    df_mean=df_grp.xs('mean', level=1, axis=0, drop_level=True)  # get mean values from each year
    df_count=df_grp.xs('count', level=1, axis=0, drop_level=True)>=num_teams  # get count values from each year that are GE to num teams
    return df_mean[df_count]

combine_dfs(year_start=1978).reset_index().set_index('Region').loc['Denver',:].T
# Out:
# Region                     Denver          Denver              Denver  \
# Team             Colorado Rockies  Denver Nuggets  Colorado Avalanche
# League                        MLB             NBA                 NHL
# Country             United States   United States       United States
# Population 2016           2853077         2853077             2853077
# B4                              4               4                   4
# State/Province           Colorado        Colorado            Colorado
# Est.                         1993            1967                1995
# 1978                          NaN           0.573                 NaN
# 1979                          NaN           0.366                 NaN
# 1980                          NaN           0.451                 NaN
# 1981                          NaN           0.561                 NaN
# 1982                          NaN           0.549                 NaN
# 1983                          NaN           0.463                 NaN
# 1984                          NaN           0.634                 NaN
# 1985                          NaN           0.573                 NaN
# 1986                          NaN           0.451                 NaN
# 1987                          NaN           0.659                 NaN
# 1988                          NaN           0.537                 NaN
# 1989                          NaN           0.524                 NaN
# 1990                          NaN           0.244                 NaN
# 1991                          NaN           0.293                 NaN
# 1992                          NaN           0.439                 NaN
# 1993                        0.414           0.512                 NaN
# 1994                        0.453             0.5                 NaN
# 1995                        0.535           0.427               0.634
# 1996                        0.512           0.256               0.652
# 1997                        0.512           0.134               0.579
# 1998                        0.475            0.28               0.598
# 1999                        0.444           0.427               0.585
# 2000                        0.506           0.488                0.72
# 2001                        0.451           0.329               0.604
# 2002                        0.451           0.207                0.64
# 2003                        0.457           0.524                0.61
# 2004                         0.42           0.598                 NaN
# 2005                        0.414           0.537               0.579
# 2006                        0.469           0.549               0.579
# 2007                        0.552            0.61               0.579
# 2008                        0.457           0.659               0.421
# 2009                        0.568           0.646               0.579
# 2010                        0.512            0.61               0.415
# 2011                        0.451           0.576               0.537
# 2012                        0.395           0.695               0.406
# 2013                        0.457           0.439               0.683
# 2014                        0.407           0.366               0.549
# 2015                         0.42           0.402                 0.5
# 2016                        0.463           0.488               0.293
# 2017                        0.537           0.561               0.579
# 2018                        0.558           0.659               0.549
# 2019                        0.438           0.662               0.657
#
# Region                   Denver            Denver
# Team             Denver Broncos  Colorado Rockies
# League                      NFL               NHL
# Country           United States     United States
# Population 2016         2853077           2853077
# B4                            4                 4
# State/Province         Colorado          Colorado
# Est.                       1960               NaN
# 1978                      0.625             0.263
# 1979                      0.625             0.319
# 1980                        0.5             0.356
# 1981                      0.625             0.306
# 1982                   0.222222               NaN
# 1983                     0.5625               NaN
# 1984                     0.8125               NaN
# 1985                     0.6875               NaN
# 1986                     0.6875               NaN
# 1987                        0.7               NaN
# 1988                        0.5               NaN
# 1989                     0.6875               NaN
# 1990                     0.3125               NaN
# 1991                       0.75               NaN
# 1992                        0.5               NaN
# 1993                     0.5625               NaN
# 1994                     0.4375               NaN
# 1995                        0.5               NaN
# 1996                     0.8125               NaN
# 1997                       0.75               NaN
# 1998                      0.875               NaN
# 1999                      0.375               NaN
# 2000                     0.6875               NaN
# 2001                        0.5               NaN
# 2002                     0.5625               NaN
# 2003                      0.625               NaN
# 2004                      0.625               NaN
# 2005                     0.8125               NaN
# 2006                     0.5625               NaN
# 2007                     0.4375               NaN
# 2008                        0.5               NaN
# 2009                        0.5               NaN
# 2010                       0.25               NaN
# 2011                        0.5               NaN
# 2012                     0.8125               NaN
# 2013                     0.8125               NaN
# 2014                       0.75               NaN
# 2015                       0.75               NaN
# 2016                     0.5625               NaN
# 2017                     0.3125               NaN
# 2018                      0.375               NaN
# 2019                     0.4375               NaN

# %% [markdown]
# Clean and plot the data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# Grab data for plotting
df_plt = group_dfs(combine_dfs(year_start=1978), num_teams=3)

# shorten long names for plot legend
df_plt.rename(columns={'Dallas–Fort Worth': 'Dallas',
                       'Miami–Fort Lauderdale': 'Miami',
                       'Minneapolis–Saint Paul': 'Minneapolis',
                       'San Francisco Bay Area': 'San Francisco',
                       'Tampa Bay Area': 'Tampa',
                       'Washington, D.C.': 'Washington DC'}, inplace=True)

# Use only midwest regions
midwest=['Chicago','Cleveland','Detroit','Minneapolis','Pittsburgh']
df_plt = df_plt[midwest]

# Drop columns that are all nans
df_plt.dropna(how='all',axis=1,inplace=True)

# Smooth the data over 3 year period
df_plt = df_plt.rolling(3, min_periods=2).mean().iloc[2:,:]

# Set legend loc
legend = 'line'

# START PLOTTING
p = df_plt.plot(figsize=(8,8), cmap='brg', legend=None)

# Clean plot
plt.box(False)  # remove frame
plt.tick_params(axis='both',length=0)  # remove ticks
plt.rc('grid',linestyle='-')   # set grid specs
plt.gca().yaxis.grid(True)    # turn on horizontal grid

# Set labelling
p.set_yticklabels(['{:,.0%}'.format(y) for y in ax.get_yticks()])  # use percentage
tit = 'Average Yearly Winning Percentage for Midwest Pro Sports Teams \nBy Metro Area'
plt.title(tit,fontsize=14,fontweight='bold')
txt = ('\nNOTE:'+
       '\n- Only including areas currently with and yearly active seasons >2'+
       '\n- Leagues used are MLB, NBA, NFL, NHL'
       '\n- Data smoothed over a 3-year period')
plt.xlabel(txt, style='italic', fontsize=8, horizontalalignment='left', x=0.05)

if legend=='line':
    # Set legend to the end of the line
    for line, name in zip(p.lines, df_plt.columns):
        y = line.get_ydata()[-1]   # get y-location of last x-point
        p.annotate(name, xy=(0.99,y), xytext=(6,0), color=line.get_color(),
                    xycoords=ax.get_yaxis_transform(), textcoords='offset points',
                    size=9, va='center')
else:  # Legend outside of plot
    # Shrink current axis by 20%
    box = plt.gca().get_position()
    plt.gca().set_position([box.x0, box.y0, box.width * 0.85, box.height])

    # # Put a legend to the right of the current axis
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5),frameon=False)
# Out:
# <img src="data:image/png;base64,..." width="800">
