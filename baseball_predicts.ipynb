# %% [markdown]
# # Predict 2022 MLB Baseball Season

# %%
import pandas as pd
import numpy as np
import os
from pybaseball import statcast

# %%
df = statcast(start_dt='2020-07-25', end_dt='2020-08-01')
# Out:
# This is a large query, it may take a moment to complete
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:07<00:00,  1.04it/s]

# %%
df
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 2152         FF 2020-08-01           95.3          -1.71           6.03
# 2239         FF 2020-08-01           95.0          -1.71           6.05
# 2336         KC 2020-08-01           76.1          -1.73           6.03
# 2411         FF 2020-08-01           95.4          -1.52           6.03
# 2515         FF 2020-08-01           95.1          -1.43           6.16
# ...         ...        ...            ...            ...            ...
# 3647         SI 2020-07-25           94.5          -1.47           5.76
# 3825         SI 2020-07-25           93.1          -1.28           5.81
# 3980         SI 2020-07-25           93.4          -1.36           5.89
# 4071         SI 2020-07-25           94.3          -1.34           5.89
# 4259         SI 2020-07-25           93.7          -1.47           5.94
#
#        player_name  batter  pitcher       events      description  ...  \
# ...
